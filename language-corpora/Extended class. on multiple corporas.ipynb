# %%
# !pip install fasttext transformers sacremoses memory-profiler
# !pip install -U kaleido
from memory_profiler import memory_usage
from matplotlib import pyplot as plt
import plotly.graph_objects as go
from sklearn.model_selection import train_test_split, cross_validate
from sklearn.model_selection import StratifiedKFold
from google.colab import drive
import pandas as pd
import plotly.express as px
import os
import json
import spacy
import re
import pickle
import sklearn
from pathlib import Path
import time
import fasttext
import torch
import torch.nn as nn
from tqdm.notebook import tqdm
import numpy as np
import torch.optim as optim
from torch.utils.tensorboard import SummaryWriter
from torch.utils.data import DataLoader
from sklearn.metrics import f1_score  
from sklearn.experimental import enable_halving_search_cv 
from sklearn.model_selection import HalvingGridSearchCV
from transformers import AutoTokenizer, AutoModel
from copy import deepcopy
import warnings
import json
from torch.utils.tensorboard import SummaryWriter
warnings.filterwarnings("ignore")

tqdm.pandas()

# %% [markdown]
# ## Description
# This notebook presents the results of classification (pos/neg) of the reviews from the Booking.com dataset.  The classification was performed using MLP, Convolution, LSTM and embedding models trained with different techniques on multiple language corporas.

# %%
drive_path = '/content/drive/'
BASE_DIR = drive_path + 'MyDrive/ColabNotebooks/studia/L3'
drive.mount(drive_path, force_remount=True)
log_dir = BASE_DIR + '/logs/'
FIGURES_DIR = BASE_DIR + "/figures"

os.makedirs(log_dir, exist_ok=True)
writer = SummaryWriter(log_dir)

booking_path = os.path.join(BASE_DIR, "booking.txt")
dataframes_path = os.path.join(BASE_DIR, "dataframes")

EMBEDDING_FILES = [
    (os.path.join(dataframes_path, "clean_inputs_clean_booking_cbow_sampled.tar.gz"), "Booking CBOW"),
    (os.path.join(dataframes_path, "clean_inputs_clean_booking_skipgram_sampled.tar.gz"), "Booking Skip-Gram"),
    (os.path.join(dataframes_path, "clean_inputs_clean_oscar_cbow_sampled.tar.gz"), "Oscar CBOW"),
    (os.path.join(dataframes_path, "clean_inputs_clean_oscar_skipgram_sampled.tar.gz"), "Oscar Skip-Gram"),
    # (os.path.join(dataframes_path, "clean_herbert.pkl"), "HerBERT"), TODO: sample
    (os.path.join(dataframes_path, "clean_kgr10_sampled.tar.gz"), "KGR10 CBOW"),
]
# Out:
# Mounted at /content/drive/

# %%
def get_training_data(df, column, max_samples):
    df = df[df[column].notnull()].sample(max_samples, random_state=1)
    return np.array(df[column].values.tolist())

def load_embeddings(path, max_samples_per_class=100):
    df = pd.read_pickle(path)
    x_res = []
    y_res = []
    for y_val, col in [(1, "vec_positive"), (0, "vec_negative")]:
        x = get_training_data(df, col, max_samples_per_class)
        x_res.append(x)
        y_res.append(np.full((x.shape[0], 1), y_val))
    
    return np.concatenate(x_res, axis=0), np.concatenate(y_res, axis=0)

# %% [markdown]
# ## Model klasyfikacji

# %%
class training_set(torch.utils.data.Dataset):
    def __init__(self,X,Y):
        self.X = torch.from_numpy(X).float()                          
        self.Y = torch.from_numpy(Y).float()                     

    def __len__(self):
        return len(self.X)                   

    def __getitem__(self, idx):
      return [self.X[idx], self.Y[idx]] 

def to_dl(x, y):
  train_data = training_set(x, y)
  return torch.utils.data.DataLoader(train_data, shuffle=False, batch_size=32)

# %%
class BookingClassifier(sklearn.base.BaseEstimator, sklearn.base.ClassifierMixin):
    def __init__(self, **kwargs):
        self.model = ...

    def init_model(self):
        pass

    def fit(self, X, y):
        # print("FIT")
        self.init_model()
        train_dl = to_dl(X, y)
        optimiser = optim.Adam(self.model.parameters())
        loss_fn = torch.nn.BCELoss()
        bar = tqdm(range(self.epochs))
        # print("le")
        for epoch in bar:
            self.model.train()
            for X_batch, y_batch in train_dl:
                X_batch = self.adjust(X_batch)
                y_pred = self.model(X_batch.cuda())
                loss = loss_fn(y_pred, y_batch.cuda())

                loss.backward()
                optimiser.step()
                optimiser.zero_grad() 
                bar.set_description(f"Loss: {loss:.4f}")
        return self

    def predict(self, X):
        return torch.round(self.model(self.adjust(torch.from_numpy(X).float().cuda())).detach().cpu()).numpy()

    def predict_proba(self, X):
        return self.model(self.adjust(torch.from_numpy(X).float().cuda())).detach().cpu().numpy()

    def adjust(self, X):
        return X

# %%
class MLP(BookingClassifier):
    def __init__(self, epochs=20, in_dim=100, hid_dim=50, layers=2, **kwargs): 
        super(MLP, self).__init__(**kwargs)
        self.hid_dim = hid_dim
        self.layers = layers
        self.epochs = epochs
        self.in_dim = in_dim

    def init_model(self):
        self.model = nn.Sequential()
        curr_in = self.in_dim
        for i in range(self.layers):
            self.model.add_module(f"lin_{i}", torch.nn.Linear(curr_in, self.hid_dim)) 
            self.model.add_module(f"lin_{i}_act" , torch.nn.ReLU())
            curr_in = self.hid_dim

        self.model.add_module("lin_last", torch.nn.Linear(curr_in, 1)) 
        self.model.add_module("last_sigm" , torch.nn.Sigmoid())
        self.model.cuda()
    
    def adjust(self, X):
        return torch.mean(X, dim=1).squeeze()
    
    def fit(self, X, y):
        return super().fit(X, y)

# %%
class LSTMReshape(nn.Module):
   
    def forward(self,x):
        out, hidden = x
        return out[: ,-1]


class RNN(BookingClassifier):
    def __init__(self, epochs=20, in_dim=100, hid_dim=50, layers=2, lin_hid=128, bi=True, dropout=0.1, **kwargs): 
        super(RNN, self).__init__(**kwargs)
        self.hid_dim = hid_dim
        self.layers = layers
        self.epochs = epochs
        self.in_dim = in_dim
        self.lin_hid = lin_hid
        self.bi = bi
        self.dropout = dropout

    def init_model(self):
        self.model = nn.Sequential()
        self.model.add_module("lstm", torch.nn.LSTM(batch_first=True, num_layers=self.layers, bidirectional=self.bi, dropout=self.dropout, input_size=self.in_dim, hidden_size=self.hid_dim))
        self.model.add_module("reshape", LSTMReshape())
        self.model.add_module("lstm_act", torch.nn.Tanh())
        # self.model.add_module("lin_pre_last", torch.nn.LazyLinear(self.lin_hid)) 
        # self.model.add_module("lin_pre_last_act", torch.nn.ReLU()) 
        self.model.add_module("lin_last", torch.nn.LazyLinear(1))  
        self.model.add_module("last_sigm" , torch.nn.Sigmoid())
        self.model.cuda()

    def fit(self, X, y):
        return super().fit(X, y)

# %%
class Conv(BookingClassifier):
    def __init__(self, epochs=20, in_dim=100, hid_ch=50, layers=2, kernel_size=2, lin_hid=128, **kwargs): 
        super(Conv, self).__init__(**kwargs)
        self.hid_ch = hid_ch
        self.layers = layers
        self.epochs = epochs
        self.in_dim = in_dim
        self.kernel_size = kernel_size
        self.lin_hid = lin_hid

    def init_model(self):
        self.model = nn.Sequential()
        curr_in = self.in_dim
        curr_ch = self.in_dim
        for i in range(self.layers):
            self.model.add_module(f"conv_{i}", torch.nn.Conv1d(curr_in, self.hid_ch, self.kernel_size)) 
            self.model.add_module(f"conv_{i}_act" , torch.nn.ReLU())
            curr_in = self.hid_ch

        self.model.add_module("pool", torch.nn.MaxPool1d(self.kernel_size)) 
        self.model.add_module("flatten", torch.nn.Flatten()) 
        # self.model.add_module("lin_pre_last", torch.nn.LazyLinear(self.lin_hid)) 
        # self.model.add_module("lin_pre_last_act", torch.nn.ReLU()) 
        self.model.add_module("lin_last", torch.nn.LazyLinear(1))  
        self.model.add_module("last_sigm" , torch.nn.Sigmoid())
        self.model.cuda()
    
    def adjust(self, X):
        return X.permute(0,2,1)
    
    def fit(self, X, y):
        return super().fit(X, y)

# %% [markdown]
# ## Uczenie i wyniki

# %%
# X, y = load_embeddings(EMBEDDING_FILES[3][0], max_samples_per_class=5000)

# %%
# X.shape

# %%
# model = RNN(**MODELS_CONFIG["LSTM"][1])
# cv_results = cross_validate(
#             model, X, y, 
#             cv=StratifiedKFold(n_splits=10, random_state=1, shuffle=True), 
#             scoring={
#                 "accuracy": "accuracy",
#                 'f1_weighted':'f1_weighted',
#                 'recall':'recall',
#                 # "memory": forward_memory_scorer
#             },
#             n_jobs=-1
#         )
# model.fit(X, y)

# cv_results

# %%
# print(model.predict(X[0:2000]), y[0:2000])
# print(y.shape[0])
# len(y[y == 1])

# %%
# model.model

# %%
def forward_memory_scorer(clf, x, y):
    try:
        return max(memory_usage((clf.predict, [x], {})))
    except:
        return 0

# %%
metrics = ["Accuracy", "F1", "Recall", "Forward time", "Fit time"] #, "Forward memory"

def run_test(model_cls, params):
    results = {}
    for path, name in tqdm(EMBEDDING_FILES):
        # print(name)
        X, y = load_embeddings(path, max_samples_per_class=5000)
        print("loaded ", X.shape)
        model = model_cls()
        params["in_dim"] = [X.shape[-1]]
        # params["in_dim"] = X.shape[-1]
        best_params = HalvingGridSearchCV(
            model,
            params, 
            resource='n_samples',
            scoring='accuracy',
            random_state=1, 
            cv=StratifiedKFold(n_splits=3, random_state=1, shuffle=True),
            verbose=1,
            n_jobs=-1,
            refit=False,
            # aggressive_elimination=True,
            # max_resources=5000
        ).fit(X, y).best_params_
        # print(params)

        model = model_cls(**best_params)
        cv_results = cross_validate(
            model, X, y, 
            cv=StratifiedKFold(n_splits=5, random_state=2, shuffle=True), 
            scoring={
                "accuracy": "accuracy",
                'f1_weighted':'f1_weighted',
                'recall':'recall',
                # "memory": forward_memory_scorer
            },
            n_jobs=3
        )
        print(cv_results)
        results[name] = {
            "Accuracy": cv_results["test_accuracy"].tolist(),
            "F1": cv_results["test_f1_weighted"].tolist(),
            "Recall": cv_results["test_recall"].tolist(),
            # "Forward memory": cv_results["test_memory"].tolist(),
            "Forward time": cv_results["score_time"].tolist(),
            "Fit time": cv_results["fit_time"].tolist(),
            "params": params
        }
    return results

# %%
MODELS_CONFIG = {
    "LSTM": (RNN, {
        "epochs": [20, 50],
        "layers": [1, 3],
        "hid_dim": [50, 100],
        # "lin_hid": [64, 128],
        "bi": [True], 
        "dropout": [0.2, 0.4]
    }),
    "Conv": (Conv, {
        "epochs": [20, 50],
        "layers": [1, 3],
        "hid_ch": [40, 60],
        "kernel_size": [2, 4],
        # "lin_hid": [64, 128],
    }),
    "MLP": (MLP, {
        "epochs": [20,  50],
        "layers": [1, 2, 3, 5],
        "hid_dim": [30, 50, 100]
    }),
}

# MODELS_CONFIG = {
#     "MLP": (MLP, {
#         "epochs": 50,
#         "layers":  3,
#         "hid_dim": 50
#     }),
#     "Conv": (Conv, {
#         "epochs": 50,
#         "layers": 1,
#         "hid_ch": 60,
#         "kernel_size": 4,
#         # "lin_hid": [64, 128],
#     }),
#     "LSTM": (RNN, {
#         "epochs": 50,
#         "layers": 1,
#         "hid_dim": 50,
#         # "lin_hid": [64, 128],
#         "bi": True, 
#         "dropout": 0.3
#     }),
    
# }

# %%
# results = {name: run_test(config[0], config[1]) for name, config in MODELS_CONFIG.items()}

results = {}
# os.system(f'rm -rf {log_dir}*')
for name, config in MODELS_CONFIG.items():
    results[name] = run_test(config[0], config[1])
    with open(os.path.join(BASE_DIR, 'results_3.json'), 'w') as f:
        json.dump(results, f)
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
# loaded  (10000, 128, 100)
# {'epochs': 50, 'layers': 3, 'hid_dim': 50, 'in_dim': 100}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
# {'fit_time': array([57.75106597, 58.1938951 , 58.23615885, 58.49484515, 58.37687635]), 'score_time': array([0.03720212, 0.03081107, 0.03192163, 0.03299403, 0.03438377]), 'test_accuracy': array([0.896, 0.836, 0.919, 0.901, 0.907]), 'test_f1_weighted': array([0.89501217, 0.83174638, 0.918554  , 0.90015491, 0.90629071]), 'test_recall': array([0.799, 0.677, 0.845, 0.809, 0.82 ])}
# loaded  (10000, 128, 100)
# {'epochs': 50, 'layers': 3, 'hid_dim': 50, 'in_dim': 100}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
# {'fit_time': array([58.41750717, 58.54174209, 58.43543196, 58.20845747, 60.99621844]), 'score_time': array([0.03271914, 0.02921176, 0.02915168, 0.02804685, 0.03352857]), 'test_accuracy': array([0.905 , 0.9115, 0.913 , 0.91  , 0.915 ]), 'test_f1_weighted': array([0.90422422, 0.91096523, 0.91243961, 0.90936045, 0.91449303]), 'test_recall': array([0.815, 0.834, 0.833, 0.826, 0.838])}
# loaded  (10000, 128, 100)
# {'epochs': 50, 'layers': 3, 'hid_dim': 50, 'in_dim': 100}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
# {'fit_time': array([67.20361066, 61.63337541, 62.86663437, 59.31912255, 59.28322363]), 'score_time': array([0.02690101, 0.03135157, 0.02685094, 0.03008795, 0.02682066]), 'test_accuracy': array([0.826 , 0.7975, 0.818 , 0.841 , 0.836 ]), 'test_f1_weighted': array([0.82125081, 0.79036394, 0.81238487, 0.83738989, 0.8318554 ]), 'test_recall': array([0.663, 0.613, 0.645, 0.692, 0.679])}
# loaded  (10000, 128, 100)
# {'epochs': 50, 'layers': 3, 'hid_dim': 50, 'in_dim': 100}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
# {'fit_time': array([58.93593454, 58.98741674, 59.30282021, 61.23019361, 62.14673257]), 'score_time': array([0.03446364, 0.03371763, 0.02782083, 0.03517985, 0.03107738]), 'test_accuracy': array([0.8335, 0.861 , 0.8455, 0.833 , 0.831 ]), 'test_f1_weighted': array([0.8292647 , 0.85889987, 0.84225161, 0.828556  , 0.82627021]), 'test_recall': array([0.676, 0.739, 0.702, 0.672, 0.666])}
# loaded  (10000, 128, 100)
# {'epochs': 50, 'layers': 3, 'hid_dim': 50, 'in_dim': 100}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
# {'fit_time': array([60.82814598, 59.63933301, 59.46607804, 59.09530354, 59.05023241]), 'score_time': array([0.0288074 , 0.03392267, 0.03332829, 0.02849174, 0.03546238]), 'test_accuracy': array([0.7915, 0.81  , 0.7345, 0.8   , 0.8045]), 'test_f1_weighted': array([0.78285768, 0.80420768, 0.71517146, 0.79345586, 0.79745503]), 'test_recall': array([0.592, 0.638, 0.474, 0.622, 0.618])}
#   0%|          | 0/5 [00:00<?, ?it/s]
# loaded  (10000, 128, 100)
# {'epochs': 50, 'layers': 1, 'hid_ch': 60, 'kernel_size': 4, 'in_dim': 100}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
# {'fit_time': array([55.55399656, 54.81396866, 55.49070883, 55.02548933, 55.51215911]), 'score_time': array([0.04138255, 0.04730701, 0.04170561, 0.04394746, 0.04628086]), 'test_accuracy': array([0.863 , 0.8815, 0.8655, 0.853 , 0.867 ]), 'test_f1_weighted': array([0.8607541 , 0.88016622, 0.86351825, 0.85031221, 0.86508953]), 'test_recall': array([0.736, 0.776, 0.745, 0.719, 0.748])}
# loaded  (10000, 128, 100)
# {'epochs': 50, 'layers': 1, 'hid_ch': 60, 'kernel_size': 4, 'in_dim': 100}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
# {'fit_time': array([55.30697584, 56.18122792, 55.49352002, 55.28658247, 55.32499051]), 'score_time': array([0.04086161, 0.04014087, 0.04255724, 0.04220223, 0.04277873]), 'test_accuracy': array([0.894 , 0.905 , 0.8685, 0.898 , 0.8785]), 'test_f1_weighted': array([0.89301402, 0.90429214, 0.86646326, 0.89707107, 0.87694255]), 'test_recall': array([0.798, 0.819, 0.745, 0.803, 0.766])}
# loaded  (10000, 128, 100)
# {'epochs': 50, 'layers': 1, 'hid_ch': 60, 'kernel_size': 4, 'in_dim': 100}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
# {'fit_time': array([54.90241027, 54.77647042, 54.49123049, 54.20304441, 56.02287221]), 'score_time': array([0.04299998, 0.04518127, 0.04286528, 0.04009438, 0.04123449]), 'test_accuracy': array([0.8055, 0.745 , 0.787 , 0.7535, 0.803 ]), 'test_f1_weighted': array([0.80093092, 0.73062593, 0.7792817 , 0.74029388, 0.79662858]), 'test_recall': array([0.654, 0.514, 0.6  , 0.528, 0.626])}
# loaded  (10000, 128, 100)
# {'epochs': 50, 'layers': 1, 'hid_ch': 60, 'kernel_size': 4, 'in_dim': 100}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
# {'fit_time': array([56.64195848, 56.80411434, 56.76825857, 56.16349006, 56.23916912]), 'score_time': array([0.04307818, 0.044029  , 0.04452586, 0.04176235, 0.03899693]), 'test_accuracy': array([0.8355, 0.8485, 0.8545, 0.8115, 0.7985]), 'test_f1_weighted': array([0.83142378, 0.84526918, 0.85156995, 0.80485729, 0.79040715]), 'test_recall': array([0.68 , 0.704, 0.714, 0.627, 0.602])}
# loaded  (10000, 128, 100)
# {'epochs': 50, 'layers': 1, 'hid_ch': 60, 'kernel_size': 4, 'in_dim': 100}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
# {'fit_time': array([52.76034212, 34.05209684, 33.73370934, 34.62857056, 34.11960411]), 'score_time': array([0.04149628, 0.03711557, 0.03895593, 0.04199862, 0.04304338]), 'test_accuracy': array([0.7055, 0.5   , 0.5   , 0.5   , 0.5   ]), 'test_f1_weighted': array([0.6842364 , 0.33333333, 0.33333333, 0.33333333, 0.33333333]), 'test_recall': array([0.446, 1.   , 1.   , 1.   , 1.   ])}
#   0%|          | 0/5 [00:00<?, ?it/s]
# loaded  (10000, 128, 100)
# {'epochs': 50, 'layers': 1, 'hid_dim': 50, 'bi': True, 'dropout': 0.3, 'in_dim': 100}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
# {'fit_time': array([82.74716473, 82.24817824, 82.3700738 , 83.17861676, 82.6752007 ]), 'score_time': array([0.05300355, 0.05265856, 0.05610347, 0.05535173, 0.05507278]), 'test_accuracy': array([0.929 , 0.9215, 0.927 , 0.917 , 0.928 ]), 'test_f1_weighted': array([0.92888622, 0.92127467, 0.92699117, 0.91663687, 0.9279262 ]), 'test_recall': array([0.889, 0.868, 0.916, 0.851, 0.896])}
# loaded  (10000, 128, 100)
# {'epochs': 50, 'layers': 1, 'hid_dim': 50, 'bi': True, 'dropout': 0.3, 'in_dim': 100}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
# {'fit_time': array([82.9241116 , 83.22846603, 84.49794698, 83.52485991, 84.15824366]), 'score_time': array([0.05283618, 0.05227304, 0.05471253, 0.05224991, 0.05832601]), 'test_accuracy': array([0.498 , 0.5005, 0.4995, 0.505 , 0.5165]), 'test_f1_weighted': array([0.33681308, 0.34140068, 0.34008216, 0.34943664, 0.37600806]), 'test_recall': array([0.005, 0.009, 0.008, 0.016, 0.042])}
# loaded  (10000, 128, 100)
# {'epochs': 50, 'layers': 1, 'hid_dim': 50, 'bi': True, 'dropout': 0.3, 'in_dim': 100}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
# {'fit_time': array([85.17907071, 87.63726687, 86.01248765, 84.1522212 , 84.11641693]), 'score_time': array([0.05231547, 0.05578613, 0.05991125, 0.05692649, 0.0598495 ]), 'test_accuracy': array([0.905 , 0.5005, 0.8765, 0.498 , 0.5025]), 'test_f1_weighted': array([0.90471175, 0.34478377, 0.8751887 , 0.33681308, 0.34488595]), 'test_recall': array([0.85 , 0.013, 0.774, 0.005, 0.012])}
# loaded  (10000, 128, 100)
# {'epochs': 50, 'layers': 1, 'hid_dim': 50, 'bi': True, 'dropout': 0.3, 'in_dim': 100}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
# {'fit_time': array([83.66513848, 84.04511189, 83.98623157, 84.57212281, 84.30518556]), 'score_time': array([0.05260682, 0.05551863, 0.05781579, 0.05427361, 0.05536342]), 'test_accuracy': array([0.5   , 0.501 , 0.5025, 0.499 , 0.5025]), 'test_f1_weighted': array([0.33510285, 0.34163307, 0.33973711, 0.33552967, 0.34403771]), 'test_recall': array([0.002, 0.009, 0.006, 0.003, 0.011])}
# loaded  (10000, 128, 100)
# {'epochs': 50, 'layers': 1, 'hid_dim': 50, 'bi': True, 'dropout': 0.3, 'in_dim': 100}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
# {'fit_time': array([84.46912384, 84.81758523, 84.05219436, 84.18989205, 83.94679832]), 'score_time': array([0.05664134, 0.05437088, 0.0549953 , 0.06041694, 0.05587411]), 'test_accuracy': array([0.497 , 0.4975, 0.501 , 0.4945, 0.5   ]), 'test_f1_weighted': array([0.3346244 , 0.34000357, 0.34333465, 0.3369133 , 0.33772641]), 'test_recall': array([0.003, 0.009, 0.011, 0.007, 0.005])}

# %%
with open(os.path.join(BASE_DIR, 'results_2.json'), 'r') as f:
    results = json.load(f)
print(results)
# Out:
# {'MLP': {'Booking CBOW': {'Accuracy': [0.896, 0.836, 0.919, 0.901, 0.907], 'F1': [0.8950121695028523, 0.8317463802388174, 0.9185540017133825, 0.9001549111681271, 0.9062907144174255], 'Recall': [0.799, 0.677, 0.845, 0.809, 0.82], 'Forward time': [0.03720211982727051, 0.030811071395874023, 0.0319216251373291, 0.03299403190612793, 0.03438377380371094], 'Fit time': [57.75106596946716, 58.19389510154724, 58.23615884780884, 58.494845151901245, 58.37687635421753], 'params': {'epochs': 50, 'layers': 3, 'hid_dim': 50, 'in_dim': 100}}, 'Booking Skip-Gram': {'Accuracy': [0.905, 0.9115, 0.913, 0.91, 0.915], 'F1': [0.9042242161508217, 0.9109652349423725, 0.9124396135265701, 0.9093604473162636, 0.9144930291699486], 'Recall': [0.815, 0.834, 0.833, 0.826, 0.838], 'Forward time': [0.03271913528442383, 0.029211759567260742, 0.02915167808532715, 0.028046846389770508, 0.03352856636047363], 'Fit time': [58.41750717163086, 58.54174208641052, 58.43543195724487, 58.208457469940186, 60.99621844291687], 'params': {'epochs': 50, 'layers': 3, 'hid_dim': 50, 'in_dim': 100}}, 'Oscar CBOW': {'Accuracy': [0.826, 0.7975, 0.818, 0.841, 0.836], 'F1': [0.8212508128465192, 0.7903639359714522, 0.8123848666747072, 0.837389893014822, 0.8318554038494861], 'Recall': [0.663, 0.613, 0.645, 0.692, 0.679], 'Forward time': [0.0269010066986084, 0.031351566314697266, 0.02685093879699707, 0.030087947845458984, 0.026820659637451172], 'Fit time': [67.20361065864563, 61.63337540626526, 62.866634368896484, 59.319122552871704, 59.2832236289978], 'params': {'epochs': 50, 'layers': 3, 'hid_dim': 50, 'in_dim': 100}}, 'Oscar Skip-Gram': {'Accuracy': [0.8335, 0.861, 0.8455, 0.833, 0.831], 'F1': [0.8292646973998756, 0.8588998655995842, 0.842251605625951, 0.8285560000780224, 0.8262702063683791], 'Recall': [0.676, 0.739, 0.702, 0.672, 0.666], 'Forward time': [0.03446364402770996, 0.03371763229370117, 0.027820825576782227, 0.035179853439331055, 0.03107738494873047], 'Fit time': [58.93593454360962, 58.98741674423218, 59.30282020568848, 61.23019361495972, 62.146732568740845], 'params': {'epochs': 50, 'layers': 3, 'hid_dim': 50, 'in_dim': 100}}, 'KGR10 CBOW': {'Accuracy': [0.7915, 0.81, 0.7345, 0.8, 0.8045], 'F1': [0.7828576814355555, 0.8042076800052761, 0.7151714643646512, 0.7934558553199575, 0.7974550302250453], 'Recall': [0.592, 0.638, 0.474, 0.622, 0.618], 'Forward time': [0.028807401657104492, 0.033922672271728516, 0.03332829475402832, 0.028491735458374023, 0.035462379455566406], 'Fit time': [60.82814598083496, 59.63933300971985, 59.46607804298401, 59.095303535461426, 59.05023241043091], 'params': {'epochs': 50, 'layers': 3, 'hid_dim': 50, 'in_dim': 100}}}, 'Conv': {'Booking CBOW': {'Accuracy': [0.863, 0.8815, 0.8655, 0.853, 0.867], 'F1': [0.8607541029260949, 0.8801662200709446, 0.8635182508823748, 0.8503122059704047, 0.8650895328750434], 'Recall': [0.736, 0.776, 0.745, 0.719, 0.748], 'Forward time': [0.041382551193237305, 0.04730701446533203, 0.04170560836791992, 0.043947458267211914, 0.046280860900878906], 'Fit time': [55.553996562957764, 54.813968658447266, 55.49070882797241, 55.02548933029175, 55.5121591091156], 'params': {'epochs': 50, 'layers': 1, 'hid_ch': 60, 'kernel_size': 4, 'in_dim': 100}}, 'Booking Skip-Gram': {'Accuracy': [0.894, 0.905, 0.8685, 0.898, 0.8785], 'F1': [0.8930140171823525, 0.9042921447022175, 0.8664632643232747, 0.8970710663740256, 0.8769425542016142], 'Recall': [0.798, 0.819, 0.745, 0.803, 0.766], 'Forward time': [0.04086160659790039, 0.04014086723327637, 0.0425572395324707, 0.04220223426818848, 0.042778730392456055], 'Fit time': [55.30697584152222, 56.181227922439575, 55.4935200214386, 55.286582469940186, 55.32499051094055], 'params': {'epochs': 50, 'layers': 1, 'hid_ch': 60, 'kernel_size': 4, 'in_dim': 100}}, 'Oscar CBOW': {'Accuracy': [0.8055, 0.745, 0.787, 0.7535, 0.803], 'F1': [0.8009309166312496, 0.7306259302648634, 0.7792817018313402, 0.7402938788110096, 0.7966285766787692], 'Recall': [0.654, 0.514, 0.6, 0.528, 0.626], 'Forward time': [0.042999982833862 ...

# %%
for metric in metrics:
    fig = go.Figure(
        layout=go.Layout(
                        template='presentation+none',
                        title=dict(
                            text=f"{metric}"
                        ),
                        barmode='overlay',
                          margin=dict(b=240),
                         xaxis=dict(tickangle=90)
                    )
    )
    traces = []
    for model, res in results.items():
        for name, data in res.items():
            n = f"{name}_{model}"
            traces.append((n, go.Box(y=data[metric], name=n, boxpoints='outliers', showlegend=False)))
            # fig.add_trace(go.Box(y=data[metric], name=n, boxpoints='outliers'))
    traces.sort(key=lambda k: k[0])
    for t in traces:
        fig.add_trace(t[1])
    fig.show(renderer='colab')
    fig.write_image(os.path.join(FIGURES_DIR, f"L3_{metric}_2.png"))
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="06bf8963-be84-4444-95a6-7633d57d7299" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("06bf8963-be84-4444-95a6-7633d57d7299")) {                    Plotly.newPlot(                        "06bf8963-be84-4444-95a6-7633d57d7299",                        [{"boxpoints":"outliers","name":"Booking CBOW_Conv","showlegend":false,"y":[0.863,0.8815,0.8655,0.853,0.867],"type":"box"},{"boxpoints":"outliers","name":"Booking CBOW_LSTM","showlegend":false,"y":[0.929,0.9215,0.927,0.917,0.928],"type":"box"},{"boxpoints":"outliers","name":"Booking CBOW_MLP","showlegend":false,"y":[0.896,0.836,0.919,0.901,0.907],"type":"box"},{"boxpoints":"outliers","name":"Booking Skip-Gram_Conv","showlegend":false,"y":[0.894,0.905,0.8685,0.898,0.8785],"type":"box"},{"boxpoints":"outliers","name":"Booking Skip-Gram_LSTM","showlegend":false,"y":[0.498,0.5005,0.4995,0.505,0.5165],"type":"box"},{"boxpoints":"outliers","name":"Booking Skip-Gram_MLP","showlegend":false,"y":[0.905,0.9115,0.913,0.91,0.915],"type":"box"},{"boxpoints":"outliers","name":"KGR10 CBOW_Conv","showlegend":false,"y":[0.7055,0.5,0.5,0.5,0.5],"type":"box"},{"boxpoints":"outliers","name":"KGR10 CBOW_LSTM","showlegend":false,"y":[0.497,0.4975,0.501,0.4945,0.5],"type":"box"},{"boxpoints":"outliers","name":"KGR10 CBOW_MLP","showlegend":false,"y":[0.7915,0.81,0.7345,0.8,0.8045],"type":"box"},{"boxpoints":"outliers","name":"Oscar CBOW_Conv","showlegend":false,"y":[0.8055,0.745,0.787,0.7535,0.803],"type":"box"},{"boxpoints":"outliers","name":"Oscar CBOW_LSTM","showlegend":false,"y":[0.905,0.5005,0.8765,0.498,0.5025],"type":"box"},{"boxpoints":"outliers","name":"Oscar CBOW_MLP","showlegend":false,"y":[0.826,0.7975,0.818,0.841,0.836],"type":"box"},{"boxpoints":"outliers","name":"Oscar Skip-Gram_Conv","showlegend":false,"y":[0.8355,0.8485,0.8545,0.8115,0.7985],"type":"box"},{"boxpoints":"outliers","name":"Oscar Skip-Gram_LSTM","showlegend":false,"y":[0.5,0.501,0.5025,0.499,0.5025],"type":"box"},{"boxpoints":"outliers","name":"Oscar Skip-Gram_MLP","showlegend":false,"y":[0.8335,0.861,0.8455,0.833,0.831],"type":"box"}],                        {"barmode":"overlay","margin":{"b":240},"template":{"data":{"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"width":3},"marker":{"size":9},"type":"scatter3d"}],"scattergeo":[{"line":{"width":3},"marker":{"size":9},"type":"scattergeo"}],"scattergl":[{"line":{"width":3},"marker":{"size":9},"type":"scattergl"}],"scatterpolargl":[{"line":{"width":3},"marker":{"size":9},"type":"scatterpolargl"}],"scatterpolar":[{"line":{"width":3},"marker":{"size":9},"type":"scatterpolar"}],"scatter":[{"line":{"width":3},"marker":{"size":9},"type":"scatter"}],"scatterternary":[{"line":{"width":3},"marker":{"size":9},"type":"scatterternary"}],"table":[{"cells":{"height":30},"header":{"height":36},"type":"table"}]},"layout":{"font":{"size":18},"xaxis":{"title":{"standoff":15}},"yaxis":{"title":{"standoff":15}}}},"title":{"text":"Accuracy"},"xaxis":{"tickangle":90}},                        {"responsive": true}                    ).then(function(){
#
# var gd = document.getElementById('06bf8963-be84-4444-95a6-7633d57d7299');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };                            </script>        </div>
# </body>
# </html>
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="94293d44-937e-4bb1-8b40-ed8f1035bb93" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("94293d44-937e-4bb1-8b40-ed8f1035bb93")) {                    Plotly.newPlot(                        "94293d44-937e-4bb1-8b40-ed8f1035bb93",                        [{"boxpoints":"outliers","name":"Booking CBOW_Conv","showlegend":false,"y":[0.8607541029260949,0.8801662200709446,0.8635182508823748,0.8503122059704047,0.8650895328750434],"type":"box"},{"boxpoints":"outliers","name":"Booking CBOW_LSTM","showlegend":false,"y":[0.9288862179487181,0.9212746684196843,0.9269911659310777,0.91663687020662,0.9279261964251393],"type":"box"},{"boxpoints":"outliers","name":"Booking CBOW_MLP","showlegend":false,"y":[0.8950121695028523,0.8317463802388174,0.9185540017133825,0.9001549111681271,0.9062907144174255],"type":"box"},{"boxpoints":"outliers","name":"Booking Skip-Gram_Conv","showlegend":false,"y":[0.8930140171823525,0.9042921447022175,0.8664632643232747,0.8970710663740256,0.8769425542016142],"type":"box"},{"boxpoints":"outliers","name":"Booking Skip-Gram_LSTM","showlegend":false,"y":[0.33681308301329943,0.3414006805526302,0.34008216339657926,0.34943663841425515,0.376008058336471],"type":"box"},{"boxpoints":"outliers","name":"Booking Skip-Gram_MLP","showlegend":false,"y":[0.9042242161508217,0.9109652349423725,0.9124396135265701,0.9093604473162636,0.9144930291699486],"type":"box"},{"boxpoints":"outliers","name":"KGR10 CBOW_Conv","showlegend":false,"y":[0.6842364002520749,0.3333333333333333,0.3333333333333333,0.3333333333333333,0.3333333333333333],"type":"box"},{"boxpoints":"outliers","name":"KGR10 CBOW_LSTM","showlegend":false,"y":[0.33462440010370864,0.3400035659508825,0.34333464929595997,0.3369133019061282,0.3377264147819464],"type":"box"},{"boxpoints":"outliers","name":"KGR10 CBOW_MLP","showlegend":false,"y":[0.7828576814355555,0.8042076800052761,0.7151714643646512,0.7934558553199575,0.7974550302250453],"type":"box"},{"boxpoints":"outliers","name":"Oscar CBOW_Conv","showlegend":false,"y":[0.8009309166312496,0.7306259302648634,0.7792817018313402,0.7402938788110096,0.7966285766787692],"type":"box"},{"boxpoints":"outliers","name":"Oscar CBOW_LSTM","showlegend":false,"y":[0.9047117530529852,0.3447837671654027,0.8751887012929592,0.33681308301329943,0.3448859459600038],"type":"box"},{"boxpoints":"outliers","name":"Oscar CBOW_MLP","showlegend":false,"y":[0.8212508128465192,0.7903639359714522,0.8123848666747072,0.837389893014822,0.8318554038494861],"type":"box"},{"boxpoints":"outliers","name":"Oscar Skip-Gram_Conv","showlegend":false,"y":[0.8314237849766825,0.8452691818339892,0.8515699537801078,0.8048572934845369,0.7904071484164429],"type":"box"},{"boxpoints":"outliers","name":"Oscar Skip-Gram_LSTM","showlegend":false,"y":[0.3351028462917356,0.3416330666441494,0.33973710919653305,0.33552966641201937,0.3440377148647316],"type":"box"},{"boxpoints":"outliers","name":"Oscar Skip-Gram_MLP","showlegend":false,"y":[0.8292646973998756,0.8588998655995842,0.842251605625951,0.8285560000780224,0.8262702063683791],"type":"box"}],                        {"barmode":"overlay","margin":{"b":240},"template":{"data":{"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"width":3},"marker":{"size":9},"type":"scatter3d"}],"scattergeo":[{"line":{"width":3},"marker":{"size":9},"type":"scattergeo"}],"scattergl":[{"line":{"width":3},"marker":{"size":9},"type":"scattergl"}],"scatterpolargl":[{"line":{"width":3},"marker":{"size":9},"type":"scatterpolargl"}],"scatterpolar":[{"line":{"width":3},"marker":{"size":9},"type":"scatterpolar"}],"scatter":[{"line":{"width":3},"marker":{"size":9},"type":"scatter"}],"scatterternary":[{"line":{"width":3},"marker":{"size":9},"type":"scatterternary"}], ...
#
# var gd = document.getElementById('94293d44-937e-4bb1-8b40-ed8f1035bb93');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };                            </script>        </div>
# </body>
# </html>
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="21636485-2a3a-48d9-a2b9-050ac52f155f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("21636485-2a3a-48d9-a2b9-050ac52f155f")) {                    Plotly.newPlot(                        "21636485-2a3a-48d9-a2b9-050ac52f155f",                        [{"boxpoints":"outliers","name":"Booking CBOW_Conv","showlegend":false,"y":[0.736,0.776,0.745,0.719,0.748],"type":"box"},{"boxpoints":"outliers","name":"Booking CBOW_LSTM","showlegend":false,"y":[0.889,0.868,0.916,0.851,0.896],"type":"box"},{"boxpoints":"outliers","name":"Booking CBOW_MLP","showlegend":false,"y":[0.799,0.677,0.845,0.809,0.82],"type":"box"},{"boxpoints":"outliers","name":"Booking Skip-Gram_Conv","showlegend":false,"y":[0.798,0.819,0.745,0.803,0.766],"type":"box"},{"boxpoints":"outliers","name":"Booking Skip-Gram_LSTM","showlegend":false,"y":[0.005,0.009,0.008,0.016,0.042],"type":"box"},{"boxpoints":"outliers","name":"Booking Skip-Gram_MLP","showlegend":false,"y":[0.815,0.834,0.833,0.826,0.838],"type":"box"},{"boxpoints":"outliers","name":"KGR10 CBOW_Conv","showlegend":false,"y":[0.446,1.0,1.0,1.0,1.0],"type":"box"},{"boxpoints":"outliers","name":"KGR10 CBOW_LSTM","showlegend":false,"y":[0.003,0.009,0.011,0.007,0.005],"type":"box"},{"boxpoints":"outliers","name":"KGR10 CBOW_MLP","showlegend":false,"y":[0.592,0.638,0.474,0.622,0.618],"type":"box"},{"boxpoints":"outliers","name":"Oscar CBOW_Conv","showlegend":false,"y":[0.654,0.514,0.6,0.528,0.626],"type":"box"},{"boxpoints":"outliers","name":"Oscar CBOW_LSTM","showlegend":false,"y":[0.85,0.013,0.774,0.005,0.012],"type":"box"},{"boxpoints":"outliers","name":"Oscar CBOW_MLP","showlegend":false,"y":[0.663,0.613,0.645,0.692,0.679],"type":"box"},{"boxpoints":"outliers","name":"Oscar Skip-Gram_Conv","showlegend":false,"y":[0.68,0.704,0.714,0.627,0.602],"type":"box"},{"boxpoints":"outliers","name":"Oscar Skip-Gram_LSTM","showlegend":false,"y":[0.002,0.009,0.006,0.003,0.011],"type":"box"},{"boxpoints":"outliers","name":"Oscar Skip-Gram_MLP","showlegend":false,"y":[0.676,0.739,0.702,0.672,0.666],"type":"box"}],                        {"barmode":"overlay","margin":{"b":240},"template":{"data":{"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"width":3},"marker":{"size":9},"type":"scatter3d"}],"scattergeo":[{"line":{"width":3},"marker":{"size":9},"type":"scattergeo"}],"scattergl":[{"line":{"width":3},"marker":{"size":9},"type":"scattergl"}],"scatterpolargl":[{"line":{"width":3},"marker":{"size":9},"type":"scatterpolargl"}],"scatterpolar":[{"line":{"width":3},"marker":{"size":9},"type":"scatterpolar"}],"scatter":[{"line":{"width":3},"marker":{"size":9},"type":"scatter"}],"scatterternary":[{"line":{"width":3},"marker":{"size":9},"type":"scatterternary"}],"table":[{"cells":{"height":30},"header":{"height":36},"type":"table"}]},"layout":{"font":{"size":18},"xaxis":{"title":{"standoff":15}},"yaxis":{"title":{"standoff":15}}}},"title":{"text":"Recall"},"xaxis":{"tickangle":90}},                        {"responsive": true}                    ).then(function(){
#
# var gd = document.getElementById('21636485-2a3a-48d9-a2b9-050ac52f155f');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };                            </script>        </div>
# </body>
# </html>
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="4f9e9861-f967-4339-ad25-10dfcc134d35" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4f9e9861-f967-4339-ad25-10dfcc134d35")) {                    Plotly.newPlot(                        "4f9e9861-f967-4339-ad25-10dfcc134d35",                        [{"boxpoints":"outliers","name":"Booking CBOW_Conv","showlegend":false,"y":[0.041382551193237305,0.04730701446533203,0.04170560836791992,0.043947458267211914,0.046280860900878906],"type":"box"},{"boxpoints":"outliers","name":"Booking CBOW_LSTM","showlegend":false,"y":[0.053003549575805664,0.0526585578918457,0.05610346794128418,0.05535173416137695,0.055072784423828125],"type":"box"},{"boxpoints":"outliers","name":"Booking CBOW_MLP","showlegend":false,"y":[0.03720211982727051,0.030811071395874023,0.0319216251373291,0.03299403190612793,0.03438377380371094],"type":"box"},{"boxpoints":"outliers","name":"Booking Skip-Gram_Conv","showlegend":false,"y":[0.04086160659790039,0.04014086723327637,0.0425572395324707,0.04220223426818848,0.042778730392456055],"type":"box"},{"boxpoints":"outliers","name":"Booking Skip-Gram_LSTM","showlegend":false,"y":[0.05283617973327637,0.05227303504943848,0.054712533950805664,0.052249908447265625,0.058326005935668945],"type":"box"},{"boxpoints":"outliers","name":"Booking Skip-Gram_MLP","showlegend":false,"y":[0.03271913528442383,0.029211759567260742,0.02915167808532715,0.028046846389770508,0.03352856636047363],"type":"box"},{"boxpoints":"outliers","name":"KGR10 CBOW_Conv","showlegend":false,"y":[0.04149627685546875,0.03711557388305664,0.0389559268951416,0.04199862480163574,0.04304337501525879],"type":"box"},{"boxpoints":"outliers","name":"KGR10 CBOW_LSTM","showlegend":false,"y":[0.056641340255737305,0.054370880126953125,0.05499529838562012,0.06041693687438965,0.05587410926818848],"type":"box"},{"boxpoints":"outliers","name":"KGR10 CBOW_MLP","showlegend":false,"y":[0.028807401657104492,0.033922672271728516,0.03332829475402832,0.028491735458374023,0.035462379455566406],"type":"box"},{"boxpoints":"outliers","name":"Oscar CBOW_Conv","showlegend":false,"y":[0.042999982833862305,0.0451812744140625,0.04286527633666992,0.04009437561035156,0.041234493255615234],"type":"box"},{"boxpoints":"outliers","name":"Oscar CBOW_LSTM","showlegend":false,"y":[0.052315473556518555,0.0557861328125,0.059911251068115234,0.05692648887634277,0.05984950065612793],"type":"box"},{"boxpoints":"outliers","name":"Oscar CBOW_MLP","showlegend":false,"y":[0.0269010066986084,0.031351566314697266,0.02685093879699707,0.030087947845458984,0.026820659637451172],"type":"box"},{"boxpoints":"outliers","name":"Oscar Skip-Gram_Conv","showlegend":false,"y":[0.04307818412780762,0.04402899742126465,0.044525861740112305,0.041762351989746094,0.03899693489074707],"type":"box"},{"boxpoints":"outliers","name":"Oscar Skip-Gram_LSTM","showlegend":false,"y":[0.052606821060180664,0.05551862716674805,0.0578157901763916,0.05427360534667969,0.05536341667175293],"type":"box"},{"boxpoints":"outliers","name":"Oscar Skip-Gram_MLP","showlegend":false,"y":[0.03446364402770996,0.03371763229370117,0.027820825576782227,0.035179853439331055,0.03107738494873047],"type":"box"}],                        {"barmode":"overlay","margin":{"b":240},"template":{"data":{"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"width":3},"marker":{"size":9},"type":"scatter3d"}],"scattergeo":[{"line":{"width":3},"marker":{"size":9},"type":"scattergeo"}],"scattergl":[{"line":{"width":3},"marker":{"size":9},"type":"scattergl"}],"scatterpolargl":[{"line":{"width":3},"marker":{"size":9},"type":"scatterpolargl"}],"scatterpolar":[{"line":{"width":3},"marker":{"size":9},"type":"scatterpolar"}],"scatter":[{"line":{"width":3},"marker":{"size":9},"type":"scat ...
#
# var gd = document.getElementById('4f9e9861-f967-4339-ad25-10dfcc134d35');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };                            </script>        </div>
# </body>
# </html>
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="cd31e504-0def-4e1a-aa4b-5e16c15a01e2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cd31e504-0def-4e1a-aa4b-5e16c15a01e2")) {                    Plotly.newPlot(                        "cd31e504-0def-4e1a-aa4b-5e16c15a01e2",                        [{"boxpoints":"outliers","name":"Booking CBOW_Conv","showlegend":false,"y":[55.553996562957764,54.813968658447266,55.49070882797241,55.02548933029175,55.5121591091156],"type":"box"},{"boxpoints":"outliers","name":"Booking CBOW_LSTM","showlegend":false,"y":[82.74716472625732,82.24817824363708,82.3700737953186,83.17861676216125,82.67520070075989],"type":"box"},{"boxpoints":"outliers","name":"Booking CBOW_MLP","showlegend":false,"y":[57.75106596946716,58.19389510154724,58.23615884780884,58.494845151901245,58.37687635421753],"type":"box"},{"boxpoints":"outliers","name":"Booking Skip-Gram_Conv","showlegend":false,"y":[55.30697584152222,56.181227922439575,55.4935200214386,55.286582469940186,55.32499051094055],"type":"box"},{"boxpoints":"outliers","name":"Booking Skip-Gram_LSTM","showlegend":false,"y":[82.92411160469055,83.22846603393555,84.49794697761536,83.52485990524292,84.15824365615845],"type":"box"},{"boxpoints":"outliers","name":"Booking Skip-Gram_MLP","showlegend":false,"y":[58.41750717163086,58.54174208641052,58.43543195724487,58.208457469940186,60.99621844291687],"type":"box"},{"boxpoints":"outliers","name":"KGR10 CBOW_Conv","showlegend":false,"y":[52.76034212112427,34.05209684371948,33.73370933532715,34.628570556640625,34.11960411071777],"type":"box"},{"boxpoints":"outliers","name":"KGR10 CBOW_LSTM","showlegend":false,"y":[84.46912384033203,84.81758522987366,84.05219435691833,84.18989205360413,83.94679832458496],"type":"box"},{"boxpoints":"outliers","name":"KGR10 CBOW_MLP","showlegend":false,"y":[60.82814598083496,59.63933300971985,59.46607804298401,59.095303535461426,59.05023241043091],"type":"box"},{"boxpoints":"outliers","name":"Oscar CBOW_Conv","showlegend":false,"y":[54.90241026878357,54.77647042274475,54.491230487823486,54.203044414520264,56.02287220954895],"type":"box"},{"boxpoints":"outliers","name":"Oscar CBOW_LSTM","showlegend":false,"y":[85.17907071113586,87.63726687431335,86.0124876499176,84.15222120285034,84.11641693115234],"type":"box"},{"boxpoints":"outliers","name":"Oscar CBOW_MLP","showlegend":false,"y":[67.20361065864563,61.63337540626526,62.866634368896484,59.319122552871704,59.2832236289978],"type":"box"},{"boxpoints":"outliers","name":"Oscar Skip-Gram_Conv","showlegend":false,"y":[56.641958475112915,56.80411434173584,56.768258571624756,56.16349005699158,56.239169120788574],"type":"box"},{"boxpoints":"outliers","name":"Oscar Skip-Gram_LSTM","showlegend":false,"y":[83.66513848304749,84.04511189460754,83.98623156547546,84.57212281227112,84.30518555641174],"type":"box"},{"boxpoints":"outliers","name":"Oscar Skip-Gram_MLP","showlegend":false,"y":[58.93593454360962,58.98741674423218,59.30282020568848,61.23019361495972,62.146732568740845],"type":"box"}],                        {"barmode":"overlay","margin":{"b":240},"template":{"data":{"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"width":3},"marker":{"size":9},"type":"scatter3d"}],"scattergeo":[{"line":{"width":3},"marker":{"size":9},"type":"scattergeo"}],"scattergl":[{"line":{"width":3},"marker":{"size":9},"type":"scattergl"}],"scatterpolargl":[{"line":{"width":3},"marker":{"size":9},"type":"scatterpolargl"}],"scatterpolar":[{"line":{"width":3},"marker":{"size":9},"type":"scatterpolar"}],"scatter":[{"line":{"width":3},"marker":{"size":9},"type":"scatter"}],"scatterternary":[{"line":{"width":3},"marker":{"size":9},"type":"scatterternary"}],"table":[{"cells":{"height":30},"header":{"height":36},"type":"tabl ...
#
# var gd = document.getElementById('cd31e504-0def-4e1a-aa4b-5e16c15a01e2');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };                            </script>        </div>
# </body>
# </html>

# %%
for model_name, res in results.items():
    headers = ["Dataset"]
    vals = [[]]
    for row_idx, (ds_name, r) in enumerate(res.items()):
        params = r['params']
        vals[0].append(ds_name)
        for col_idx, (n, v) in enumerate(params.items()):
            if len(headers) <= len(params):
                headers.append(n)
            if len(vals) <= col_idx+1:
                vals.append([])
            vals[col_idx+1].append(v)
    fig = go.Figure(
        data=[go.Table(header=dict(values=headers),cells=dict(values=vals))],
        layout=go.Layout(
                        template='presentation+none',
                        title=dict(
                            text=f"Params: {model_name}"
                        ),
                        barmode='overlay'
                    )
    )
    fig.show(renderer='colab')
    fig.write_image(os.path.join(FIGURES_DIR, f"L3_{model_name}_params_2.png"))
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="5aaadbc4-25b7-46b2-ad47-db25c51a2061" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5aaadbc4-25b7-46b2-ad47-db25c51a2061")) {                    Plotly.newPlot(                        "5aaadbc4-25b7-46b2-ad47-db25c51a2061",                        [{"cells":{"values":[["Booking CBOW","Booking Skip-Gram","Oscar CBOW","Oscar Skip-Gram","KGR10 CBOW"],[50,50,50,50,50],[3,3,3,3,3],[50,50,50,50,50],[100,100,100,100,100]]},"header":{"values":["Dataset","epochs","layers","hid_dim","in_dim"]},"type":"table"}],                        {"barmode":"overlay","template":{"data":{"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"width":3},"marker":{"size":9},"type":"scatter3d"}],"scattergeo":[{"line":{"width":3},"marker":{"size":9},"type":"scattergeo"}],"scattergl":[{"line":{"width":3},"marker":{"size":9},"type":"scattergl"}],"scatterpolargl":[{"line":{"width":3},"marker":{"size":9},"type":"scatterpolargl"}],"scatterpolar":[{"line":{"width":3},"marker":{"size":9},"type":"scatterpolar"}],"scatter":[{"line":{"width":3},"marker":{"size":9},"type":"scatter"}],"scatterternary":[{"line":{"width":3},"marker":{"size":9},"type":"scatterternary"}],"table":[{"cells":{"height":30},"header":{"height":36},"type":"table"}]},"layout":{"font":{"size":18},"xaxis":{"title":{"standoff":15}},"yaxis":{"title":{"standoff":15}}}},"title":{"text":"Params: MLP"}},                        {"responsive": true}                    ).then(function(){
#
# var gd = document.getElementById('5aaadbc4-25b7-46b2-ad47-db25c51a2061');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };                            </script>        </div>
# </body>
# </html>
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="4040c192-a2c7-4e7b-ab07-b204dea780a4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4040c192-a2c7-4e7b-ab07-b204dea780a4")) {                    Plotly.newPlot(                        "4040c192-a2c7-4e7b-ab07-b204dea780a4",                        [{"cells":{"values":[["Booking CBOW","Booking Skip-Gram","Oscar CBOW","Oscar Skip-Gram","KGR10 CBOW"],[50,50,50,50,50],[1,1,1,1,1],[60,60,60,60,60],[4,4,4,4,4],[100,100,100,100,100]]},"header":{"values":["Dataset","epochs","layers","hid_ch","kernel_size","in_dim"]},"type":"table"}],                        {"barmode":"overlay","template":{"data":{"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"width":3},"marker":{"size":9},"type":"scatter3d"}],"scattergeo":[{"line":{"width":3},"marker":{"size":9},"type":"scattergeo"}],"scattergl":[{"line":{"width":3},"marker":{"size":9},"type":"scattergl"}],"scatterpolargl":[{"line":{"width":3},"marker":{"size":9},"type":"scatterpolargl"}],"scatterpolar":[{"line":{"width":3},"marker":{"size":9},"type":"scatterpolar"}],"scatter":[{"line":{"width":3},"marker":{"size":9},"type":"scatter"}],"scatterternary":[{"line":{"width":3},"marker":{"size":9},"type":"scatterternary"}],"table":[{"cells":{"height":30},"header":{"height":36},"type":"table"}]},"layout":{"font":{"size":18},"xaxis":{"title":{"standoff":15}},"yaxis":{"title":{"standoff":15}}}},"title":{"text":"Params: Conv"}},                        {"responsive": true}                    ).then(function(){
#
# var gd = document.getElementById('4040c192-a2c7-4e7b-ab07-b204dea780a4');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };                            </script>        </div>
# </body>
# </html>
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="65426aa0-274a-4f30-8e54-fa27ced9d009" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("65426aa0-274a-4f30-8e54-fa27ced9d009")) {                    Plotly.newPlot(                        "65426aa0-274a-4f30-8e54-fa27ced9d009",                        [{"cells":{"values":[["Booking CBOW","Booking Skip-Gram","Oscar CBOW","Oscar Skip-Gram","KGR10 CBOW"],[50,50,50,50,50],[1,1,1,1,1],[50,50,50,50,50],[true,true,true,true,true],[0.3,0.3,0.3,0.3,0.3],[100,100,100,100,100]]},"header":{"values":["Dataset","epochs","layers","hid_dim","bi","dropout","in_dim"]},"type":"table"}],                        {"barmode":"overlay","template":{"data":{"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"width":3},"marker":{"size":9},"type":"scatter3d"}],"scattergeo":[{"line":{"width":3},"marker":{"size":9},"type":"scattergeo"}],"scattergl":[{"line":{"width":3},"marker":{"size":9},"type":"scattergl"}],"scatterpolargl":[{"line":{"width":3},"marker":{"size":9},"type":"scatterpolargl"}],"scatterpolar":[{"line":{"width":3},"marker":{"size":9},"type":"scatterpolar"}],"scatter":[{"line":{"width":3},"marker":{"size":9},"type":"scatter"}],"scatterternary":[{"line":{"width":3},"marker":{"size":9},"type":"scatterternary"}],"table":[{"cells":{"height":30},"header":{"height":36},"type":"table"}]},"layout":{"font":{"size":18},"xaxis":{"title":{"standoff":15}},"yaxis":{"title":{"standoff":15}}}},"title":{"text":"Params: LSTM"}},                        {"responsive": true}                    ).then(function(){
#
# var gd = document.getElementById('65426aa0-274a-4f30-8e54-fa27ced9d009');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };                            </script>        </div>
# </body>
# </html>
